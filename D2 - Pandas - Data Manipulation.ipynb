# %%
import pandas as pd

# %%
data = pd.read_csv("https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv")

# %%
data.head()
# Out:
#    id  location_id              address_1 address_2          city
# 0   1            1  2600 Middlefield Road       NaN  Redwood City  \
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.dtypes    # shows datatypes of each column
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.info()  # gives brief info about dataset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
 df.describe()   # gives little statistical analysis of dataset
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp
# count   891.000000  891.000000  891.000000  714.000000  891.000000  \
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
 df.describe(include = "all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex
# count    891.000000  891.000000  891.000000                      891   891  \
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
# df[["Name","Ticket","Sex"]].describe()

type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.dtypes == "object"
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name            True
# Sex             True
# Age            False
# SibSp          False
# Parch          False
# Ticket          True
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.dtypes[df.dtypes == "object"]
# Out:
# Name        object
# Sex         object
# Ticket      object
# Cabin       object
# Embarked    object
# dtype: object

# %%
df.dtypes[df.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
df[df.dtypes[df.dtypes == "object"].index]
# Out:
#                                                   Name     Sex
# 0                              Braund, Mr. Owen Harris    male  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
df[df.dtypes[df.dtypes == "object"].index].describe()
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# where survived = 0:
df[df["Survived"] == 0]
# Out:
#      PassengerId  Survived  Pclass                                      Name
# 0              1         0       3                   Braund, Mr. Owen Harris  \
# 4              5         0       3                  Allen, Mr. William Henry
# 5              6         0       3                          Moran, Mr. James
# 6              7         0       1                   McCarthy, Mr. Timothy J
# 7              8         0       3            Palsson, Master. Gosta Leonard
# ..           ...       ...     ...                                       ...
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %%
df[(df["Survived"] == 0) & (df["Sex"] == "male")]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex
# 0              1         0       3         Braund, Mr. Owen Harris  male  \
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 881          882         0       3              Markun, Mr. Johann  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df[(df["Survived"] == 0) & (df["Sex"] == "male")].count()
# Out:
# PassengerId    468
# Survived       468
# Pclass         468
# Name           468
# Sex            468
# Age            360
# SibSp          468
# Parch          468
# Ticket         468
# Fare           468
# Cabin           62
# Embarked       468
# dtype: int64

# %%
len(df[(df["Survived"] == 0) & (df["Sex"] == "male")])  # no. of male died is 468
# Out:
# 468

# %%
len(df[(df["Survived"] == 0) & (df["Sex"] == "female")]) # no.of female died is 81
# Out:
# 81

# %%
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
len(df[df["Sex"] == "male"])
# Out:
# 577

# %%
# name of person who have paid highest fare:
df[["Fare"]].max()
# Out:
# Fare    512.3292
# dtype: float64

# %%
df[df["Fare"] == max(df["Fare"])]
# Out:
#      PassengerId  Survived  Pclass                                Name
# 258          259         1       1                    Ward, Miss. Anna  \
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 737          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
df[df["Fare"] == max(df["Fare"])][["Name"]]
# Out:
#                                    Name
# 258                    Ward, Miss. Anna
# 679  Cardeza, Mr. Thomas Drake Martinez
# 737              Lesurer, Mr. Gustave J

# %%
df[df["Fare"] == max(df["Fare"])][["Name","Survived"]]
# Out:
#                                    Name  Survived
# 258                    Ward, Miss. Anna         1
# 679  Cardeza, Mr. Thomas Drake Martinez         1
# 737              Lesurer, Mr. Gustave J         1

# %%
df[df["Fare"] == min(df["Fare"])][["Name","Survived"]]
# Out:
#                                  Name  Survived
# 179               Leonard, Mr. Lionel         0
# 263             Harrison, Mr. William         0
# 271      Tornquist, Mr. William Henry         1
# 277       Parkes, Mr. Francis "Frank"         0
# 302   Johnson, Mr. William Cahoone Jr         0
# 413    Cunningham, Mr. Alfred Fleming         0
# 466             Campbell, Mr. William         0
# 481  Frost, Mr. Anthony Wood "Archie"         0
# 597               Johnson, Mr. Alfred         0
# 633     Parr, Mr. William Henry Marsh         0
# 674        Watson, Mr. Ennis Hastings         0
# 732              Knight, Mr. Robert J         0
# 806            Andrews, Mr. Thomas Jr         0
# 815                  Fry, Mr. Richard         0
# 822   Reuchlin, Jonkheer. John George         0

# %%
df[df["Cabin"].isnull() == False]
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df[df["Cabin"].isnull() == False])   # no. of people who received cabin
# Out:
# 204

# %%
# Adding new column :
df["new_col"] = "bhumik"

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col
# 0      0         A/5 21171   7.2500   NaN        S  bhumik
# 1      0          PC 17599  71.2833   C85        C  bhumik
# 2      0  STON/O2. 3101282   7.9250   NaN        S  bhumik
# 3      0            113803  53.1000  C123        S  bhumik
# ...

# %%
# duplicate column
df["Name_new"] = df["Name"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col
# 0      0         A/5 21171   7.2500   NaN        S  bhumik  \
# 1      0          PC 17599  71.2833   C85        C  bhumik
# 2      0  STON/O2. 3101282   7.9250   NaN        S  bhumik
# 3      0            113803  53.1000  C123        S  bhumik
# ...

# %%
df["age_pclass"]  = df["Age"] + df["Pclass"]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col
# 0      0         A/5 21171   7.2500   NaN        S  bhumik  \
# 1      0          PC 17599  71.2833   C85        C  bhumik
# 2      0  STON/O2. 3101282   7.9250   NaN        S  bhumik
# 3      0            113803  53.1000  C123        S  bhumik
# ...

# %%
# Deleting the column : 
df.drop("new_col",axis = 1)
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 0                              Braund, Mr. Owen Harris    male  22.0      1  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()   # not deleted permanently, becz inplace = False(by default)
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked new_col
# 0      0         A/5 21171   7.2500   NaN        S  bhumik  \
# 1      0          PC 17599  71.2833   C85        C  bhumik
# 2      0  STON/O2. 3101282   7.9250   NaN        S  bhumik
# 3      0            113803  53.1000  C123        S  bhumik
# ...

# %%
df.drop("new_col",axis = 1,inplace = True)  # or we can do reassignment operation

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S  \
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
# Row Level Operation :
df.drop(0)   # deleted index 0, but not deleted permanentl
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# 5                                     Moran, Mr. James    male   NaN      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S  \
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
#
# ...

# %%
df = df.drop(0)

# %%
df.head(2)
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C  \
# 2      0  STON/O2. 3101282   7.9250   NaN        S
#
#                                             Name_new  age_pclass
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        39.0
# 2                             Heikkinen, Miss. Laina        29.0

# %%
# fetching row 1 :
df.iloc[0]  # iloc - index location (goes by default(inbuilt) index location)
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name_new       Cumings, Mrs. John Bradley (Florence Briggs Th...
# age_pclass                                                  39.0
# Name: 1, dtype: object

# %%
df.loc[1]   # goes by named indexing
# Out:
# PassengerId                                                    2
# Survived                                                       1
# Pclass                                                         1
# Name           Cumings, Mrs. John Bradley (Florence Briggs Th...
# Sex                                                       female
# Age                                                         38.0
# SibSp                                                          1
# Parch                                                          0
# Ticket                                                  PC 17599
# Fare                                                     71.2833
# Cabin                                                        C85
# Embarked                                                       C
# Name_new       Cumings, Mrs. John Bradley (Florence Briggs Th...
# age_pclass                                                  39.0
# Name: 1, dtype: object

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C  \
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
#
#                                             Name_new  age_pclass
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...        39.0
# 2                             Heikkinen, Miss. Laina        29.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)        36.0

# %%
# fetching from index 2 to index 5:

df.loc[2:5]
# Out:
#    PassengerId  Survived  Pclass
# 2            3         1       3  \
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                            Name     Sex   Age  SibSp  Parch
# 2                        Heikkinen, Miss. Laina  female  26.0      0      0  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
# 5                              Moran, Mr. James    male   NaN      0      0
#
#              Ticket     Fare Cabin Embarked
# 2  STON/O2. 3101282   7.9250   NaN        S  \
# 3            113803  53.1000  C123        S
# 4            373450   8.0500   NaN        S
# 5            330877   8.4583   NaN        Q
#
#                                        Name_new  age_pclass
# 2                        Heikkinen, Miss. Laina        29.0
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)        36.0
# ...

# %%
df.loc[101:106]
# Out:
#      PassengerId  Survived  Pclass                              Name     Sex
# 101          102         0       3  Petroff, Mr. Pastcho ("Pentcho")    male  \
# 102          103         0       1         White, Mr. Richard Frasar    male
# 103          104         0       3        Johansson, Mr. Gustaf Joel    male
# 104          105         0       3    Gustafsson, Mr. Anders Vilhelm    male
# 105          106         0       3             Mionoff, Mr. Stoytcho    male
# 106          107         1       3  Salkjelsvik, Miss. Anna Kristine  female
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 101   NaN      0      0   349215   7.8958   NaN        S  \
# 102  21.0      0      1    35281  77.2875   D26        S
# 103  33.0      0      0     7540   8.6542   NaN        S
# 104  37.0      2      0  3101276   7.9250   NaN        S
# 105  28.0      0      0   349207   7.8958   NaN        S
# 106  21.0      0      0   343120   7.6500   NaN        S
#
# ...

# %%
df.loc[101:106,["Survived","Pclass"]]  # subset of the dataset
# Out:
#      Survived  Pclass
# 101         0       3
# 102         0       1
# 103         0       3
# 104         0       3
# 105         0       3
# 106         1       3

# %%
df.loc[3:4,["Fare","Cabin","Embarked"]]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
df.iloc[2:4,[9,10,11]]
# Out:
#     Fare Cabin Embarked
# 3  53.10  C123        S
# 4   8.05   NaN        S

# %%
df.iloc[:,[0,2]]
# Out:
#      PassengerId  Pclass
# 1              2       1
# 2              3       3
# 3              4       1
# 4              5       3
# 5              6       3
# ..           ...     ...
# 886          887       2
# 887          888       1
# 888          889       3
# 889          890       1
# 890          891       3
#
# [890 rows x 2 columns]

# %%
df.iloc[2:5:2,[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
df.iloc[[2,4],[0,1,2]]
# Out:
#    PassengerId  Survived  Pclass
# 3            4         1       1
# 5            6         0       3

# %%
# Records where age > 35

df[df["Age"] > 35]
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 6              7         0       1
# 11            12         1       1
# 13            14         0       3
# 15            16         1       2
# ..           ...       ...     ...
# 865          866         1       2
# 871          872         1       1
# 873          874         0       3
# 879          880         1       1
# 885          886         0       3
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 15                    Hewlett, Mrs. (Mary D Kingcome)   female  55.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[(df["Age"] > 35) & (df["Pclass"] == 1)]
# Out:
#      PassengerId  Survived  Pclass
# 1              2         1       1  \
# 6              7         0       1
# 11            12         1       1
# 30            31         0       1
# 35            36         0       1
# ..           ...       ...     ...
# 856          857         1       1
# 857          858         1       1
# 862          863         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 30                            Uruchurtu, Don. Manuel E    male  40.0      0
# 35                      Holverson, Mr. Alexander Oskar    male  42.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df1 = df.iloc[1:5, [2,3,4,5,9,10]]

# %%
df1
# Out:
#    Pclass                                          Name     Sex   Age
# 2       3                        Heikkinen, Miss. Laina  female  26.0  \
# 3       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4       3                      Allen, Mr. William Henry    male  35.0
# 5       3                              Moran, Mr. James    male   NaN
#
#       Fare Cabin
# 2   7.9250   NaN
# 3  53.1000  C123
# 4   8.0500   NaN
# 5   8.4583   NaN

# %%
# renaming indexes :
# keeping indexes as name 
df1.set_index("Name",inplace=True)

# %%
# dropping records(row) where we have null value
df1.dropna()
# Out:
#                                               Pclass     Sex   Age  Fare Cabin
# Name
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1  C123

# %%
df1.dropna(axis = 1)  # dropped column which has null value
# Out:
#                                               Pclass     Sex     Fare
# Name
# Heikkinen, Miss. Laina                             3  female   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  53.1000
# Allen, Mr. William Henry                           3    male   8.0500
# Moran, Mr. James                                   3    male   8.4583

# %%
df1.dropna(axis = 1,thresh = 1) 
# thresh - require that many non - NA values,
# Out:
#                                               Pclass     Sex   Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %%
df1.dropna(axis = 1,thresh = 2)  # dropped cabin column
# Out:
#                                               Pclass     Sex   Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583

# %%
df1.dropna(axis = 1,thresh = 4)  # dropped age column, atleast 4 non NA value required
# Out:
#                                               Pclass     Sex     Fare
# Name
# Heikkinen, Miss. Laina                             3  female   7.9250
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  53.1000
# Allen, Mr. William Henry                           3    male   8.0500
# Moran, Mr. James                                   3    male   8.4583

# %%
df1
# Out:
#                                               Pclass     Sex   Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %%
df1.dropna(axis = 0,thresh = 4)  # row level ,atleast  non-NA value is required
# Out:
#                                               Pclass     Sex   Age    Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.925  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.100
# Allen, Mr. William Henry                           3    male  35.0   8.050
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN

# %%
# replacing null value

df1.fillna("bhumi")
# Out:
#                                               Pclass     Sex    Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female   26.0   7.9250  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female   35.0  53.1000
# Allen, Mr. William Henry                           3    male   35.0   8.0500
# Moran, Mr. James                                   3    male  bhumi   8.4583
#
#                                               Cabin
# Name
# Heikkinen, Miss. Laina                        bhumi
# Futrelle, Mrs. Jacques Heath (Lily May Peel)   C123
# Allen, Mr. William Henry                      bhumi
# Moran, Mr. James                              bhumi

# %%
df1.fillna(df1["Age"].mean())
# Out:
#                                               Pclass     Sex   Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male  32.0   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                        32.0
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                      32.0
# Moran, Mr. James                              32.0

# %%
df1.groupby("Sex").count()
# Out:
#         Pclass  Age  Fare  Cabin
# Sex
# female       2    2     2      1
# male         2    1     2      0

# %%
# Avg age of female and male group:
# df1.groupby("Sex").mean()
# df1.groupby("Sex").mean()["Age"]

# %%
# Total fair paid by female and male i.e how many revenue generated by male and female
df1.groupby("Sex").sum()["Fare"]
# Out:
# Sex
# female    61.0250
# male      16.5083
# Name: Fare, dtype: float64

# %%
df1
# Out:
#                                               Pclass     Sex   Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin
# Name
# Heikkinen, Miss. Laina                         NaN
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123
# Allen, Mr. William Henry                       NaN
# Moran, Mr. James                               NaN

# %%
df2 = df.iloc[0:4 , 0:5]

# %%
df2
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
# Concatenation Operation

pd.concat([df1,df2])   # horizontal(rowwise) concatenation
# Out:
#                                               Pclass     Sex   Age     Fare
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
# 1                                                  1  female   NaN      NaN
# 2                                                  3  female   NaN      NaN
# 3                                                  1  female   NaN      NaN
# 4                                                  3    male   NaN      NaN
#
#                                              Cabin  PassengerId  Survived
# Heikkinen, Miss. Laina                         NaN          NaN       NaN  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123          NaN       NaN
# ...

# %%
pd.concat([df1,df2], axis = 1)   # vertical(columnwize) concatenation
# Out:
#                                               Pclass     Sex   Age     Fare
# Heikkinen, Miss. Laina                           3.0  female  26.0   7.9250  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)     1.0  female  35.0  53.1000
# Allen, Mr. William Henry                         3.0    male  35.0   8.0500
# Moran, Mr. James                                 3.0    male   NaN   8.4583
# 1                                                NaN     NaN   NaN      NaN
# 2                                                NaN     NaN   NaN      NaN
# 3                                                NaN     NaN   NaN      NaN
# 4                                                NaN     NaN   NaN      NaN
#
#                                              Cabin  PassengerId  Survived
# Heikkinen, Miss. Laina                         NaN          NaN       NaN  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123          NaN       NaN
# ...

# %%
# Divide the passenger class by 3:
df1["new_col"] = df1["Pclass"]

# %%
df1
# Out:
#                                               Pclass     Sex   Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin  new_col
# Name
# Heikkinen, Miss. Laina                         NaN        3
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123        1
# Allen, Mr. William Henry                       NaN        3
# Moran, Mr. James                               NaN        3

# %%
df1["new_col"] = df1["Pclass"].apply(lambda x : x/3)

# %%
df1
# Out:
#                                               Pclass     Sex   Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin   new_col
# Name
# Heikkinen, Miss. Laina                         NaN  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123  0.333333
# Allen, Mr. William Henry                       NaN  1.000000
# Moran, Mr. James                               NaN  1.000000

# %%
def func1(x):
    return x/3

# %%
df1["new_col1"] = df1["Pclass"].apply(func1)

# %%
df1
# Out:
#                                               Pclass     Sex   Age     Fare
# Name
# Heikkinen, Miss. Laina                             3  female  26.0   7.9250  \
# Futrelle, Mrs. Jacques Heath (Lily May Peel)       1  female  35.0  53.1000
# Allen, Mr. William Henry                           3    male  35.0   8.0500
# Moran, Mr. James                                   3    male   NaN   8.4583
#
#                                              Cabin   new_col  new_col1
# Name
# Heikkinen, Miss. Laina                         NaN  1.000000  1.000000
# Futrelle, Mrs. Jacques Heath (Lily May Peel)  C123  0.333333  0.333333
# Allen, Mr. William Henry                       NaN  1.000000  1.000000
# Moran, Mr. James                               NaN  1.000000  1.000000

# %%
df2
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                             Heikkinen, Miss. Laina  female
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                           Allen, Mr. William Henry    male

# %%
df2["new_col"] = df2["Name"].apply(lambda x : len(x))

# %%
df2["len_name"] = df2["Name"].apply(len)

# %%
def func2(x):
    return len(x)

# %%
df2["new_col1"] = df2["Name"].apply(func2)

# %%
df2
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  new_col
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female       51  \
# 2                             Heikkinen, Miss. Laina  female       22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       44
# 4                           Allen, Mr. William Henry    male       24
#
#    len_name  new_col1
# 1        51        51
# 2        22        22
# 3        44        44
# 4        24        24

# %%
# wherever passenger id lesser than 3, keep that data as it is , passenger id greter than equal to 3, replace it with logaritmic:
import math
def cust1(x):
    if x < 3:
        return x
    else:
        return math.log10(x)

# %%
df2["PassengerId_filter"] = df2["PassengerId"].apply(cust1)

# %%
df2
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex  new_col
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female       51  \
# 2                             Heikkinen, Miss. Laina  female       22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female       44
# 4                           Allen, Mr. William Henry    male       24
#
#    len_name  new_col1  PassengerId_filter
# 1        51        51            2.000000
# 2        22        22            0.477121
# 3        44        44            0.602060
# 4        24        24            0.698970

# %%
# in sex column replace female by 1, and male by 0 :
def test2(x):
    if x == "female":
        return 1
    else:
        return 0

# %%
df2["Sex"] = df2["Sex"].apply(test2)

# %%
df2
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex  new_col  len_name
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    1       51        51  \
# 2                             Heikkinen, Miss. Laina    1       22        22
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    1       44        44
# 4                           Allen, Mr. William Henry    0       24        24
#
#    new_col1  PassengerId_filter
# 1        51            2.000000
# 2        22            0.477121
# 3        44            0.602060
# 4        24            0.698970

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          686
# Embarked         2
# Name_new         0
# age_pclass     177
# dtype: int64

# %%
# seperating entire data in 3 categories
#  0-100 : "A"
#  101 - 199 : "B"
#  200 + : "C"

def test3(x):
    if x < 100:
        return "A"
    elif 100 < x < 200:
        return "B"
    else:
        return "C"

# %%
df["Fare_grp"] = df["Fare"].apply(test3)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 1            2         1       1  \
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
#
#                                                 Name     Sex   Age  SibSp
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1  \
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 1      0          PC 17599  71.2833   C85        C  \
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# 5      0            330877   8.4583   NaN        Q
#
# ...

# %%
df["Fare_grp"].value_counts()
# Out:
# Fare_grp
# A    837
# B     33
# C     20
# Name: count, dtype: int64
