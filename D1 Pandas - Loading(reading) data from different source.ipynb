# %%
import pandas as pd

# %%
# reading a csv(comma seperated value) file
data = pd.read_csv("https://raw.githubusercontent.com/codeforamerica/ohana-api/master/data/sample-csv/addresses.csv")

# %%
data.head()  # by default, reads the very first line as header
# Out:
#    id  location_id              address_1 address_2          city
# 0   1            1  2600 Middlefield Road       NaN  Redwood City  \
# 1   2            2       24 Second Avenue       NaN     San Mateo
# 2   3            3       24 Second Avenue       NaN     San Mateo
# 3   4            4       24 Second Avenue       NaN     San Mateo
# 4   5            5       24 Second Avenue       NaN     San Mateo
#
#   state_province postal_code country
# 0             CA       94063      US
# 1             CA       94401      US
# 2             CA       94403      US
# 3             CA       94401      US
# 4             CA       94401      US

# %%
 type(data)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
#     DataFrame in one of the data type format which is available inside the pandas library

# %%
data.tail(6)
# Out:
#     id  location_id                   address_1  address_2
# 15  16           16         1161 South Bernardo        NaN  \
# 16  17           17     409 South Spruce Avenue        NaN
# 17  18           18            114 Fifth Avenue        NaN
# 18  19           19         19 West 39th Avenue        NaN
# 19  20           21          123 El Camino Real        NaN
# 20  21           22  2013 Avenue of the fellows  Suite 100
#
#                    city state_province postal_code country
# 15            Sunnyvale             CA       94087      US
# 16  South San Francisco             CA       94080      US
# 17         Redwood City             CA       94063      US
# 18            San Mateo             CA       94403      US
# 19              Belmont             CA       94002      US
# 20        San Francisco             CA       94103      US

# %%
data.columns # gives list of all columns name
# Out:
# Index(['id', 'location_id', 'address_1', 'address_2', 'city', 'state_province',
#        'postal_code', 'country'],
#       dtype='object')

# %%
list(data.columns)
# Out:
# ['id',
#  'location_id',
#  'address_1',
#  'address_2',
#  'city',
#  'state_province',
#  'postal_code',
#  'country']

# %%
# column selection
data[["id","address_1"]]  # passing column name as a list,if we want multiple column
# Out:
#     id                   address_1
# 0    1       2600 Middlefield Road
# 1    2            24 Second Avenue
# 2    3            24 Second Avenue
# 3    4            24 Second Avenue
# 4    5            24 Second Avenue
# 5    6           800 Middle Avenue
# 6    7              500 Arbor Road
# 7    8           800 Middle Avenue
# 8    9       2510 Middlefield Road
# 9   10       1044 Middlefield Road
# 10  11         2140 Euclid Avenue.
# 11  12       1044 Middlefield Road
# 12  13         399 Marine Parkway.
# 13  14          660 Veterans Blvd.
# 14  15        1500 Valencia Street
# 15  16         1161 South Bernardo
# 16  17     409 South Spruce Avenue
# 17  18            114 Fifth Avenue
# 18  19         19 West 39th Avenue
# 19  20          123 El Camino Real
# 20  21  2013 Avenue of the fellows

# %%
data["state_province"]  #  passing as a simple plan string
# Out:
# 0     CA
# 1     CA
# 2     CA
# 3     CA
# 4     CA
# 5     CA
# 6     CA
# 7     CA
# 8     CA
# 9     CA
# 10    CA
# 11    CA
# 12    CA
# 13    CA
# 14    CA
# 15    CA
# 16    CA
# 17    CA
# 18    CA
# 19    CA
# 20    CA
# Name: state_province, dtype: object

# %%
data[["state_province"]]   # passing as a list
# Out:
#    state_province
# 0              CA
# 1              CA
# 2              CA
# 3              CA
# 4              CA
# 5              CA
# 6              CA
# 7              CA
# 8              CA
# 9              CA
# 10             CA
# 11             CA
# 12             CA
# 13             CA
# 14             CA
# 15             CA
# 16             CA
# 17             CA
# 18             CA
# 19             CA
# 20             CA

# %%
type(data["state_province"])
# Out:
# pandas.core.series.Series

# %%
type(data[["state_province"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# data["id","address_1"]  #will give error

# %% [markdown]
#     Series is a subset of a dataframe(combination or collection of series0)

# %%
# !pip install xlrd
# Out:
# ...
#      -------------------------------------- 96.5/96.5 kB 290.5 kB/s eta 0:00:00
# ...

# %%
# reading excel sheet:
pd.read_excel("airline.xlsx")
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
pd.read_excel("airline.xlsx",sheet_name = "Sheet1")
# Out:
#     YEAR       Y      W       R      L      K
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
pd.read_excel("airline.xlsx",sheet_name = "Sheet3",header = None)
# Out:
#        0       1      2       3      4      5
# 0   1948   1.214  0.243  0.1454  1.415  0.612
# 1   1949   1.354  0.260  0.2181  1.384  0.559
# 2   1950   1.569  0.278  0.3157  1.388  0.573
# 3   1951   1.948  0.297  0.3940  1.550  0.564
# 4   1952   2.265  0.310  0.3559  1.802  0.574
# 5   1953   2.731  0.322  0.3593  1.926  0.711
# 6   1954   3.025  0.335  0.4025  1.964  0.776
# 7   1955   3.562  0.350  0.3961  2.116  0.827
# 8   1956   3.979  0.361  0.3822  2.435  0.800
# 9   1957   4.420  0.379  0.3045  2.707  0.921
# 10  1958   4.563  0.391  0.3284  2.706  1.067
# 11  1959   5.385  0.426  0.3856  2.846  1.083
# 12  1960   5.554  0.441  0.3193  3.089  1.481
# 13  1961   5.465  0.460  0.3079  3.122  1.736
# 14  1962   5.825  0.485  0.3783  3.184  1.926
# 15  1963   6.876  0.506  0.4180  3.263  2.041
# 16  1964   7.823  0.538  0.5163  3.412  1.997
# 17  1965   9.120  0.564  0.5879  3.623  2.257
# 18  1966  10.512  0.586  0.5369  4.074  2.742
# ...

# %%
data1 = pd.read_excel("airline.xlsx",sheet_name = "Sheet3",header = None, names = ['a','b','c','d','e','f'])  # renaming/changing column name

# %%
data1.head()
# Out:
#       a      b      c       d      e      f
# 0  1948  1.214  0.243  0.1454  1.415  0.612
# 1  1949  1.354  0.260  0.2181  1.384  0.559
# 2  1950  1.569  0.278  0.3157  1.388  0.573
# 3  1951  1.948  0.297  0.3940  1.550  0.564
# 4  1952  2.265  0.310  0.3559  1.802  0.574

# %%
## saving a file
# data1,to_csv("test1.csv")
# data1,to_csv("test1.csv", index = False)
# data1,to_excel("test1.xlsx", index = False)    #---saving as a excel format

# %%
# reading from github directly
df = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# reading from html(hypertext markup language)
data2 = pd.read_html("https://www.basketball-reference.com/leagues/")

# %%
type(data2)
# Out:
# list

# %%
len(data2)
# Out:
# 1

# %%
data2[0]
# Out:
#    Unnamed: 0_level_0 Unnamed: 1_level_0     Unnamed: 2_level_0
#                Season                 Lg               Champion
# 0             2023-24                NBA                    NaN  \
# 1             2022-23                NBA         Denver Nuggets
# 2             2021-22                NBA  Golden State Warriors
# 3             2020-21                NBA        Milwaukee Bucks
# 4             2019-20                NBA     Los Angeles Lakers
# ..                ...                ...                    ...
# 82            1950-51                NBA       Rochester Royals
# 83            1949-50                NBA     Minneapolis Lakers
# 84            1948-49                BAA     Minneapolis Lakers
# 85            1947-48                BAA      Baltimore Bullets
# 86            1946-47                BAA  Philadelphia Warriors
#
#        Award Winners                              Top Performers
#                  MVP Rookie of the Year                   Points
# ...

# %%
# data2[0].to_csv("player.csv")
